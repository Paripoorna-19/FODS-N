# %%
import pandas as pd
df1=pd.read_csv("/content/Absenteeism_at_work.csv", sep=";")
df1
# Out:
#      ID  Reason for absence  Month of absence  Day of the week  Seasons  \
# 0    11                  26                 7                3        1
# 1    36                   0                 7                3        1
# 2     3                  23                 7                4        1
# 3     7                   7                 7                5        1
# 4    11                  23                 7                5        1
# ..   ..                 ...               ...              ...      ...
# 735  11                  14                 7                3        1
# 736   1                  11                 7                3        1
# 737   4                   0                 0                3        1
# 738   8                   0                 0                4        2
# 739  35                   0                 0                6        3
#
#      Transportation expense  Distance from Residence to Work  Service time  \
# ...

# %%
#2. drop the columns not required for your analysis
#going to drop columns service time and son

# df1['Social drinker']
df1.drop(['Service time', 'Son'], axis=1)
# Out:
#      ID  Reason for absence  Month of absence  Day of the week  Seasons  \
# 0    11                  26                 7                3        1
# 1    36                   0                 7                3        1
# 2     3                  23                 7                4        1
# 3     7                   7                 7                5        1
# 4    11                  23                 7                5        1
# ..   ..                 ...               ...              ...      ...
# 735  11                  14                 7                3        1
# 736   1                  11                 7                3        1
# 737   4                   0                 0                3        1
# 738   8                   0                 0                4        2
# 739  35                   0                 0                6        3
#
#      Transportation expense  Distance from Residence to Work  Age  \
# ...

# %%
#3 
#i doing a missing value analysis
# df1.iloc[:, 0:].describe(na=True)
df1.info()
df1.fillna("-")
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 740 entries, 0 to 739
# Data columns (total 21 columns):
#  #   Column                           Non-Null Count  Dtype
# ---  ------                           --------------  -----
#  0   ID                               740 non-null    int64
#  1   Reason for absence               740 non-null    int64
#  2   Month of absence                 740 non-null    int64
#  3   Day of the week                  740 non-null    int64
#  4   Seasons                          740 non-null    int64
#  5   Transportation expense           740 non-null    int64
#  6   Distance from Residence to Work  740 non-null    int64
#  7   Service time                     740 non-null    int64
#  8   Age                              740 non-null    int64
#  9   Work load Average/day            740 non-null    float64
#  10  Hit target                       740 non-null    int64
#  11  Disciplinary failure             740 non-null    int64
# ...

# %%
#4.outlier analysis of Transportation expaense
import matplotlib.pyplot as plt
plt.boxplot(df1['Transportation expense'])
plt.xticks([1], ["Transportation expense"])
plt.show()
print("There are some outliers in Transportation expense")
#print("no of outliers for transportation expense:- ", df1.query((df1['Transportation expense']<df1['Transportation expense'].min()) or(df1['Transportation expense']>df1['Transportation expense'].max()) )['Transportation expense'].count())
#printing outliers for transportation expense
# df1['Transportation expense']

#outlier analysis of weight

plt.boxplot(df1['Weight'])
plt.xticks([1], ["Weight"])
plt.show()
# Out:
# There are some outliers in Transportation expense

# %%
#5.correlation analysis of two variables age and transportation expense
df1[['Age', 'Transportation expense']].corr()
# Out:
#                              Age  Transportation expense
# Age                     1.000000               -0.227542
# Transportation expense -0.227542                1.000000

# %%
#6. describe the data
df1.describe()
# Out:
#                ID  Reason for absence  Month of absence  Day of the week  \
# count  740.000000          740.000000        740.000000       740.000000
# mean    18.017568           19.216216          6.324324         3.914865
# std     11.021247            8.433406          3.436287         1.421675
# min      1.000000            0.000000          0.000000         2.000000
# 25%      9.000000           13.000000          3.000000         3.000000
# 50%     18.000000           23.000000          6.000000         4.000000
# 75%     28.000000           26.000000          9.000000         5.000000
# max     36.000000           28.000000         12.000000         6.000000
#
#           Seasons  Transportation expense  Distance from Residence to Work  \
# count  740.000000              740.000000                       740.000000
# mean     2.544595              221.329730                        29.631081
# std      1.111831               66.952223                        14.836788
# ...

# %%
#7. first 3 rows
#df1.head(3)
df1.iloc[0:3, :]
# Out:
#    ID  Reason for absence  Month of absence  Day of the week  Seasons  \
# 0  11                  26                 7                3        1
# 1  36                   0                 7                3        1
# 2   3                  23                 7                4        1
#
#    Transportation expense  Distance from Residence to Work  Service time  Age  \
# 0                     289                               36            13   33
# 1                     118                               13            18   50
# 2                     179                               51            18   38
#
#    Work load Average/day   ...  Disciplinary failure  Education  Son  \
# 0                 239.554  ...                     0          1    2
# 1                 239.554  ...                     1          1    1
# 2                 239.554  ...                     0          1    0
#
#    Social drinker  Social smoker  Pet  Weight  Height  Body mass index  \
# ...

# %%
#8. last 4 rows
df1.tail(4)
# Out:
#      ID  Reason for absence  Month of absence  Day of the week  Seasons  \
# 736   1                  11                 7                3        1
# 737   4                   0                 0                3        1
# 738   8                   0                 0                4        2
# 739  35                   0                 0                6        3
#
#      Transportation expense  Distance from Residence to Work  Service time  \
# 736                     235                               11            14
# 737                     118                               14            13
# 738                     231                               35            14
# 739                     179                               45            14
#
#      Age  Work load Average/day   ...  Disciplinary failure  Education  Son  \
# 736   37                 264.604  ...                     0          3    1
# ...

# %%
#9.first row corresponding to the last 3 digits of your Roll No 
df1.iloc[245, :]
# Out:
# ID                                  30.000
# Reason for absence                  25.000
# Month of absence                     7.000
# Day of the week                      2.000
# Seasons                              1.000
# Transportation expense             157.000
# Distance from Residence to Work     27.000
# Service time                         6.000
# Age                                 29.000
# Work load Average/day              275.312
# Hit target                          98.000
# Disciplinary failure                 0.000
# Education                            1.000
# Son                                  0.000
# Social drinker                       1.000
# Social smoker                        1.000
# Pet                                  0.000
# Weight                              75.000
# Height                             185.000
# Body mass index                     22.000
# Absenteeism time in hours            3.000
# Name: 245, dtype: float64

# %%
#10.how many rows of data you have
#either df1.shape[0] or len(df1)
df1.shape[0]
# Out:
# 740

# %%
#11. display the first 5 columns of the first row
df1.iloc[0, 0:5]
# Out:
# ID                    11.0
# Reason for absence    26.0
# Month of absence       7.0
# Day of the week        3.0
# Seasons                1.0
# Name: 0, dtype: float64

# %%
#12  count thenumber of people affected with the diseases of  the circulatory 
df2=pd.read_csv("/content/cardio_train.csv", sep=";")
df2.groupby("cardio")["id"].count()[1]
# Out:
# 34979

# %%
#13.	Split people according to their body mass index into two groups: overweight (25 to 30) and obese (>30).

# df1.value_counts("Body mass index")

df1.groupby(['Body mass index', 'Weight'])['Age'].count()
# Out:
# Body mass index  Weight
# 19               56         46
# 21               58          7
#                  65          8
#                  68          7
# 22               63         20
#                  65          8
#                  75          7
# 23               65         45
#                  67         30
# 24               68          6
#                  69         77
#                  76          3
# 25               69          8
#                  70         15
#                  73         37
#                  75         12
#                  77          6
#                  79          3
#                  84         16
#                  95         29
# 27               80         24
# 28               83         55
#                  94          4
# 29               88         23
# 30               90         40
# 31               89        113
#                  98         34
# 32               86         24
# 33               88          6
# ...

# %%
#14. Average age of  highschoolers (b) Average age of graduates  (c) Average age of postgraduates

print("averages")
print(df1.groupby("Education")['Age'].mean())
print("standard deviation")
df1.groupby("Education")['Age'].std()
# Out:
# averages
# Education
# 1    37.142390
# 2    34.000000
# 3    32.291139
# 4    41.000000
# Name: Age, dtype: float64
# standard deviation
# Education
# 1    6.639007
# 2    5.501515
# 3    3.105627
# 4    0.000000
# Name: Age, dtype: float64

# %%
#15. mean and variance of transportation expenses
mean_1=df1['Transportation expense'].mean()
var_1=(df1['Transportation expense'].std()) *(df1['Transportation expense'].std())
print("mean: ", mean_1)
print("var: ", var_1)
# Out:
# mean:  221.32972972972973
# var:  4482.600197491131

# %%
#16. histogram for age of social drinks
a=[1,21,41,61,81,101]#for having binsize is 20
plt.hist(df1['Age'][df1['Social drinker']==1],a,rwidth=0.2, histtype="stepfilled")

plt.hist()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-95-36f07535dbc6> in <module>
#       3 plt.hist(df1['Age'][df1['Social drinker']==1],a,rwidth=0.2, histtype="stepfilled")
#       4
# ----> 5 plt.hist()
#
# TypeError: hist() missing 1 required positional argument: 'x'

# %%
#skew of this distribution
a=df1['Age'][df1['Social drinker']==1].skew()
print("skewness: ",a)
if a>0:
  print("skewness is positive")
elif(a==0):
  print("skewness is zero")
else:
  print("skewness is Negative")
# Out:
# skewness:  0.5083426436631391
# skewness is positive
